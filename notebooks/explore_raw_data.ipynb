# %%
import os
import pandas as pd
from sqlalchemy import create_engine
from dotenv import load_dotenv

# Load .env from project root
load_dotenv()

DATABASE_URL = os.getenv("DATABASE_URL")
if not DATABASE_URL:
    raise ValueError("DATABASE_URL not found")

engine = create_engine(DATABASE_URL)

# Load raw data
df_raw = pd.read_sql("SELECT * FROM stg_mb_listings;", engine)
print(df_raw.shape)
df_raw.head()
# Out:
# (9600, 14)
#                                          pk       source  \
# 0  55a4644367416f785efee880ec877989001589b4  magicbricks
# 1  8f0e6ae4edd9a9e13fd4cdc6340de9f9f0ca10d2  magicbricks
# 2  26234327a3b03822448240e2a2395fe98920dc1c  magicbricks
# 3  0593bcc9a1d8c1ab835cd88ff31279cd0582a646  magicbricks
# 4  460fa48f68e36c64e5f5fefc243f89650eea0299  magicbricks
#
#                                      source_page_url  card_index  \
# 0  https://www.magicbricks.com/property-for-rent-...           1
# 1  https://www.magicbricks.com/property-for-rent-...           2
# 2  https://www.magicbricks.com/property-for-rent-...           3
# 3  https://www.magicbricks.com/property-for-rent-...           4
# 4  https://www.magicbricks.com/property-for-rent-...           5
#
#                                                title  price_inr  bhk  \
# 0         1 BHK Apartment for Rent in Bhandup Mumbai    35000.0  1.0
# 1      1 BHK House for Rent in Kandivali East Mumbai    25000.0  1.0
# 2  1 BHK Apartment for Rent in shree shubh chs Bo...    29000.0  1.0
# 3  3 BHK Apartment for Rent in Ghatkopar West Mumbai   160000.0  3.0
# 4    1 BHK Apartment for Rent in Bhandup West Mumbai    22000.0  1.0
#
#    bathrooms  area_sqft    city  \
# 0        NaN      450.0  Mumbai
# 1        1.0      400.0  Mumbai
# 2        NaN      450.0  Mumbai
# 3        NaN     1170.0  Mumbai
# 4        7.0      380.0  Mumbai
#
#                                            image_url  \
# 0  https://img.staticmb.com/mbphoto/property/crop...
# 1  https://img.staticmb.com/mbphoto/property/crop...
# 2  https://img.staticmb.com/mbphoto/property/crop...
# 3  ......
# 4  ......
#
#                                            card_text  \
# 0  3 + Photos Posted: Yesterday Owner: Sushma kad...
# 1  12 + Photos Updated today Owner: Dr Navin Punj...
# 2  9 + Photos Updated today Owner: Narendra 1 BHK...
# 3  13 + Photos Updated today Owner: M S Duggal Pr...
# 4  6 + Photos Updated today Owner: Naya Ghar Prem...
#
#                first_seen_at               last_seen_at
# 0 2025-08-29 19:08:42.234546 2025-08-29 19:08:42.234546
# 1 2025-08-29 19:08:42.243910 2025-08-29 19:08:42.243910
# 2 2025-08-29 19:08:42.245994 2025-08-29 19:08:42.245994
# 3 2025-08-29 19:08:42.248227 2025-08-29 19:08:42.248227
# 4 2025-08-29 19:08:42.250400 2025-08-29 19:08:42.250400
